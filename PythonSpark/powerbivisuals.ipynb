# %%
# %pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)

# Initialize Chrome WebDriver
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the Power BI report URL
driver.get("https://app.powerbi.com/groups/me/reports/6e3243a2-6cbf-44e7-9eaa-78f150d44fe8/ReportSection?experience=power-bi&clientSideAuth=0")

# Wait for the visual to load (you may need to adjust the wait time)
driver.implicitly_wait(10)

# Find the visual element by its class name
visual_element = driver.find_element_by_class_name("visualContainerHost")

# Take a screenshot of the visual
visual_element.screenshot("power_bi_visual.png")

# Close the browser
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

def capture_power_bi_chart(url, username, password, power_bi_report_name, output_path):
    # Set up the browser driver
    driver = webdriver.Chrome(executable_file='"C:\Program Files\Google\Chrome\Application\chrome.exe"')

    try:
        # Open Power BI Service and log in
        driver.get(url)
        time.sleep(2)

        # Enter username and password
        driver.find_element(By.ID, 'i0116').send_keys(username)
        driver.find_element(By.ID, 'idSIButton9').click()
        time.sleep(2)

        driver.find_element(By.ID, 'i0118').send_keys(password)
        driver.find_element(By.ID, 'idSIButton9').click()
        time.sleep(2)

        # Navigate to the report/dashboard
        driver.get(f"https://app.powerbi.com/groups/me/reports/6e3243a2-6cbf-44e7-9eaa-78f150d44fe8/ReportSection?experience=power-bi&clientSideAuth=0")
        time.sleep(5)

        # Take a screenshot of the entire page
        driver.save_screenshot(output_path)

    finally:
        # Close the browser
        driver.quit()

# Replace with your Power BI credentials and report details
power_bi_url = 'https://app.powerbi.com/home?experience=power-bi&clientSideAuth=0'
power_bi_username = 'ayushi.khandal@kmgin.in'
power_bi_password = 'ayushi@2025$$'
power_bi_report_name = 'IMS Pipeline'
output_image_path = 'screenshot.png'

# Capture the Power BI chart
capture_power_bi_chart(power_bi_url, power_bi_username, power_bi_password, power_bi_report_name, output_image_path)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

def capture_power_bi_chart(url, username, password, power_bi_report_name, output_path):
    # Open Power BI Service and log in
    driver = webdriver.Chrome()  # Let Selenium manage the WebDriver

    try:
        driver.get(url)
        time.sleep(2)

        # Enter username and password
        driver.find_element(By.ID, 'i0116').send_keys(username)
        driver.find_element(By.ID, 'idSIButton9').click()
        time.sleep(2)

        driver.find_element(By.ID, 'i0118').send_keys(password)
        driver.find_element(By.ID, 'idSIButton9').click()
        time.sleep(2)

        # Navigate to the report/dashboard
        driver.get(f"https://app.powerbi.com/groups/me/reports/6e3243a2-6cbf-44e7-9eaa-78f150d44fe8/ReportSection?experience=power-bi&clientSideAuth=0")
        time.sleep(5)

        # Take a screenshot of the entire page
        driver.save_screenshot(output_path)

    finally:
        # Close the browser
        driver.quit()

# Replace with your Power BI credentials and report details
power_bi_url = 'https://app.powerbi.com/home?experience=power-bi&clientSideAuth=0'
power_bi_username = 'ayushi.khandal@kmgin.in'
power_bi_password = 'ayushi@2025$$'
power_bi_report_name = 'IMS Pipeline'
output_image_path = 'screenshot.png'

# Capture the Power BI chart
capture_power_bi_chart(power_bi_url, power_bi_username, power_bi_password, power_bi_report_name, output_image_path)

# %%
import requests

# Replace 'https://app.powerbi.com/groups/me/reports/reportId/visuals/visualId' with the actual link
visual_link = 'https://app.powerbi.com/groups/b0ae7a1c-44b0-4581-bbf7-e63b9e5ffb4a/reports/6e3243a2-6cbf-44e7-9eaa-78f150d44fe8/ReportSection?ctid=b9edde28-a188-4c9d-9f55-621432f7f11d&pbi_source=shareVisual&visual=7354c3aba991dcd80b19&height=272.60&width=706.55&bookmarkGuid=99b2d21d-b7e5-4ab3-b168-1270d195081a'

# Send a GET request to the visual link
response = requests.get(visual_link)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Save the image as an image file
    with open('power_bi_visual.pptx', 'wb') as f:
        f.write(response.content)
else:
    print(f'Failed to download image. Status code: {response.status_code}')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)
chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration
chrome_options.add_argument("--no-sandbox")  # Disable the sandbox
chrome_options.add_argument("--disable-dev-shm-usage")  # Disable shared memory usage
chrome_options.add_argument("--start-maximized")  # Start Chrome maximized

# Set up ChromeDriver
driver = webdriver.Chrome()

# Navigate to the Power BI report
driver.get('https://app.powerbi.com/groups/b0ae7a1c-44b0-4581-bbf7-e63b9e5ffb4a/reports/6e3243a2-6cbf-44e7-9eaa-78f150d44fe8/ReportSection?ctid=b9edde28-a188-4c9d-9f55-621432f7f11d&pbi_source=shareVisual&visual=7354c3aba991dcd80b19&height=272.60&width=706.55&bookmarkGuid=99b2d21d-b7e5-4ab3-b168-1270d195081a')

# Wait for the page to load (you may need to adjust the wait time)
driver.implicitly_wait(10)

# Capture the screenshot of the entire page
screenshot = driver.get_screenshot_as_png()

# Save the screenshot as an image file
with open('power_bi_visual.bmp', 'wb') as f:
    f.write(screenshot)

# Close the browser
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Set up Chrome options (remove headless for testing)
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)
chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration
chrome_options.add_argument("--no-sandbox")  # Disable the sandbox
chrome_options.add_argument("--disable-dev-shm-usage")  # Disable shared memory usage
chrome_options.add_argument("--start-maximized")  # Start Chrome maximized

# Set up ChromeDriver
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the Power BI report
driver.get('https://app.powerbi.com/links/eBmJ7xOtDN?ctid=b9edde28-a188-4c9d-9f55-621432f7f11d&pbi_source=linkShare&bookmarkGuid=e6decda3-21a0-4291-8b7d-a5eca75dd8a0')

# Wait for the page to load (you may need to adjust the wait time)
driver.implicitly_wait(10)

# Capture the screenshot (use PNG format)
screenshot = driver.get_screenshot_as_png()

# Save the screenshot as an image file
with open('power_bi.png', 'wb') as f:
    f.write(screenshot)

# Close the browser
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Set up Chrome options (remove headless for testing)
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)
chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration
chrome_options.add_argument("--no-sandbox")  # Disable the sandbox
chrome_options.add_argument("--disable-dev-shm-usage")  # Disable shared memory usage
chrome_options.add_argument("--start-maximized")  # Start Chrome maximized

# Set up ChromeDriver
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the Power BI report
report_url = 'https://app.powerbi.com/links/eBmJ7xOtDN?ctid=b9edde28-a188-4c9d-9f55-621432f7f11d&pbi_source=linkShare&bookmarkGuid=e6decda3-21a0-4291-8b7d-a5eca75dd8a0'
driver.get(report_url)

# Wait for the page to load (you may need to adjust the wait time)
driver.implicitly_wait(10)

# Find the specific visual element (replace with the correct CSS selector)
visual_element = driver.find_element_by_css_selector('.your-visual-css-selector')

# Capture the screenshot of the visual element (use PNG format)
screenshot = visual_element.screenshot_as_png

# Save the screenshot as an image file
with open('power_bi_visual.png', 'wb') as f:
    f.write(screenshot)

# Close the browser
driver.quit()

# %%
from flask import Flask, request, jsonify
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

app = Flask(__name__)

# Set up Chrome options (remove headless for testing)
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no GUI)
chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration
chrome_options.add_argument("--no-sandbox")  # Disable the sandbox
chrome_options.add_argument("--disable-dev-shm-usage")  # Disable shared memory usage
chrome_options.add_argument("--start-maximized")  # Start Chrome maximized

# Set up ChromeDriver
driver = webdriver.Chrome(options=chrome_options)

@app.route('/get_visuals', methods=['GET'])
def get_visuals():
    try:
        # Get report ID from query parameters
        report_id = request.args.get('report_id')

        # Construct the Power BI report URL
        report_url = f'https://app.powerbi.com/reportEmbed?reportId=6e3243a2-6cbf-44e7-9eaa-78f150d44fe8&autoAuth=true&ctid=b9edde28-a188-4c9d-9f55-621432f7f11d'

        # Navigate to the Power BI report
        driver.get(report_url)

        # Wait for the page to load (you may need to adjust the wait time)
        driver.implicitly_wait(10)

        # Capture the screenshot (use PNG format)
        screenshot = driver.get_screenshot_as_png()

        # Save the screenshot as an image file (you can modify the filename)
        with open('power_bi_visual.png', 'wb') as f:
            f.write(screenshot)

        return jsonify({"message": "Visual captured successfully!"})

    except Exception as e:
        return jsonify({"error": str(e)})

if __name__ == '__main__':
    app.run(debug=True)

# %%
# %pip install adal
# Out:
# ...
#   Obtaining dependency information for adal from https://files.pythonhosted.org/packages/49/8d/58008a9a86075827f99aa8bb75d8db515bb9c34654f95e647cda31987db7/adal-1.2.7-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for PyJWT<3,>=1.0.0 from https://files.pythonhosted.org/packages/2b/4f/e04a8067c7c96c364cef7ef73906504e2f40d690811c021e1a1901473a19/PyJWT-2.8.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for cryptography>=1.1.0 from https://files.pythonhosted.org/packages/36/33/ed48350d38a6a151dd3cf1850a5966b86c5752212ddaaceb44e65bf412e5/cryptography-42.0.5-cp37-abi3-win_amd64.whl.metadata
# ...
# Using cached adal-1.2.7-py2.py3-none-any.whl (55 kB)
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB 5.7 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/2.9 MB 8.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.9 MB 12.9 MB/s eta 0:00:01
# ...

# %%
import adal

AUTHORITY_URL = 'https://login.windows.net/common'
RESOURCE = 'https://app.powerbi.com/home?experience=power-bi&clientSideAuth=0'
CLIENT_ID = 'ea0616ba-638b-4df5-95b9-636659ae5121'
userid = 'ayushi.khandal@kmgin.in'
userpassword = 'ayushi@2025$$'


context = adal.AuthenticationContext(AUTHORITY_URL,validate_authority=True,api_version=None)
token = context.acquire_token_with_username_password(RESOURCE,userid,userpassword,CLIENT_ID)
access_token = token['accessToken']
print(access_token)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
# ...
