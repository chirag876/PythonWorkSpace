# %%
# %pip install --upgrade openai
# %pip install typing-extensions --upgrade
# %pip install --upgrade typing-extensions
# %pip uninstall typing-extensions
# %pip install typing-extensions
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Chirag\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import openai
import csv
import json
import pandas as pd
from openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import openai
#       2 import csv
#       3 import json
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\openai\__init__.py:8
#       5 import os as _os
#       6 from typing_extensions import override
# ----> 8 from . import types
#       9 from ._types import NoneType, Transport, ProxiesTypes
#      10 from ._utils import file_from_path
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\openai\types\__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless.
#       3 from __future__ import annotations
# ----> 5 from .edit import Edit as Edit
#       6 from .image import Image as Image
# ...

# %%
mapping_df = pd.read_csv('data_less.csv')
mapping_df
# Out:
#                                       MGA  \
# 0  Arrowhead General Insurance Agency Inc
# 1          Plimsoll Specialty Markets LLC
# 2               Marsh USA Chicago, Inc.,
# 3                 Marsh & McLennan Agency
# 4                    Travers & Associates
# 5                        Wings Insurance
# 6          Halton Hall & Associates, Inc.
# 7             Avion Insurance Agency, Inc
# 8                       Daniel Abrahamsen
#
#                              Program Name  \
# 0  Arrowhead ES Primary General Liability
# 1                            Non Admitted
# 2                            Non Admitted
# 3                            Non Admitted
# 4                            Non Admitted
# 5                            Non Admitted
# 6                            Non Admitted
# 7                            Non Admitted
# 8                                     NaN
#
#                           Issuing Company Full policy number  \
# ...

# %%
source_col_df = pd.read_csv("source_cols.csv")
source_col_df
# Out:
#                     Agent;MGA;Managing General Agent
# 0                              Program Name;Admitted
# 1                          Issuing Company;Market Co
# 2                       Full policy number; Policy #
# 3                    Policy Effective Date;Eff. Date
# 4                   Policy Expiration Date;Exp. Date
# ..                                               ...
# 59                    Broker/Agent Zip;Agent Zipcode
# 60                           Direct/Assumed;'Direct'
# 61                                              Fac?
# 62                  Fac Reinsurance Attachment point
# 63  IRPM (Individual Risk Premium Modification);IRPM
#
# [64 rows x 1 columns]

# %%
OPENAI_API_KEY="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"

# %%
# Specify the path to the CSV file
file_path = r'C:\Workspaces\CodeSpaces\Python_Work\ChatGpt_AzureAI\data_less.csv'
# Open the CSV file in read mode
with open(file_path, 'r') as f:
    # Read the CSV data using the csv.reader
    data = list(csv.reader(f))
    # Extract headers from the first row
    headers = data[0]
    # Extract data excluding the headers
    header_data = data[1:]

# Now, you have 'headers' containing column names and 'datas' containing the actual data

# %%
headers = list(csv.reader(mapping_df))
headers
# Out:
# [['MGA'],
#  ['Program Name'],
#  ['Issuing Company'],
#  ['Full policy number'],
#  ['Policy Effective Date'],
#  ['Policy Expiration Date'],
#  ['Insured Name'],
#  ['Insured Address'],
#  ['Insured City'],
#  ['Insured State'],
#  ['Insured Zip'],
#  ['Transaction Effective Date'],
#  ['Transaction Expiration Date'],
#  ['Premium'],
#  ['Terrorism Premium'],
#  ['Total Gross Premium including Terrorism'],
#  ['Commission amount'],
#  ['Net Premium'],
#  ['Surcharge amount'],
#  ['Surcharge type'],
#  ['Tax Amount'],
#  ['Tax Type'],
#  ['Fee Amount'],
#  ['Fee Type'],
#  ['Payment terms'],
#  ['Book or Process Date'],
#  ['Policy Type'],
#  ['Transaction Type'],
#  ['Primary/Excess Indicator'],
#  ['Attachment Point'],
#  ['CM/Occ Indicator'],
#  ['Retroactive date'],
#  ['Risk/Location #'],
#  ['Risk/Location Address'],
#  ['Risk/Location City'],
#  ['Risk/Location State'],
#  ['Risk/Location Zip'],
#  ['Risk/Location premium'],
#  ['Technical Price'],
# ...

# %%
source_header = list(csv.reader(source_col_df))
source_header
# Out:
# [['Agent;MGA;Managing General Agent']]

# %%
# Iterate through each row of header in 'header_data'
for headers in header_data:
    print(headers)
# Out:
# ['Arrowhead General Insurance Agency Inc', 'Arrowhead ES Primary General Liability', 'TSIC', 'TSAHGL0000025-00', '06/25/2023', '06/17/2024', 'Rego Realty Corporation', '154 WESTLAND ST', 'HARTFORD', 'CT', '6120', '08-04-2023', '06/17/2024', '500', '15', '515', '87.55', '427.45', '0', '', '0', '', '0', '', 'Agent Statement Bill Full Pay', '08-07-2023', 'New Business', 'Endorsement', 'Primary', '', 'Occurrence', '', '1', '154 WESTLAND ST', 'HARTFORD', 'CT', '6120', '500', '0', '0', '0', '0', '1000000', '2000000', 'Deductible', '25000', 'Per Occurrence', '6531', '17.1001', 'All Other Liability Occurrence', '', '08-07-2023', '0-5', '100', '2000000', 'RSG Specialty LLC', '5565 Glenridge Connector, Suite 550', 'Atlanta', 'GA', '30342', 'Direct', 'N', '100000', 'NO', '0', '1000000', '2000000', '', '1000000']
# ...

# %%
# Initialization of 'pairs' List
pairs = []

# Iterate through each row in the DataFrame
for index, headers in mapping_df.iterrows():
    # Create a prompt string based on the current row
    prompt = (
        f"You are provided with a dataset featuring three key columns: data element, Description, and Alternative_names."
        f"The data element column contains predefined names, serving as reference points for matching incoming inputs."
        f"Your objective is to analyze the dataset, linking incoming inputs to the values of these predetermined data element names."
        f"In the Alternative_names column, you'll discover additional names linked to each data element value, separated by ';'."
        f"For example, let's focus on the current entry: {headers[0]} with a description of {headers[1]} and alternative names {headers[2]}, separated by ';'."
        f"Your task is to establish connections between incoming inputs and these fixed data element values."
    )
    # prompt = (
    #     f"You are provided with a dataset containing columns and it their data"
    #     f"The columns in the provided data are predefined, serving as reference points for mapping incoming columns from another dataset."
    #     f"Your objective is to analyze the dataset, linking incoming inputs columns to the columns of the predefined columns of the provided dataset."
    #     # f"In the Alternative_names column, you'll discover additional names linked to each data element value, separated by ';'."
    #     f"For example, let's focus on column{headers[0]} with some data and {headers[1]} with some data and so one till {headers[69]} in our provided dataset."
    #     f"Your task is to establish connections between columns from another dataset and The columns in the provided dataset."
    # )
    
    mpt = (
        f"Examine the provided dataset with column name {data}."
        f"Alternative names for this column include: {source_header}."
        # f"Consider the provided {len(non_null_data)} non-null values to identify patterns and characteristics."
        f"Attempt to learn any similar and different patterns, such as data types, common values, or trends."
        f"Pay attention to any potential relationships between data points within each column of the provided dataset."
        # f"If there are null values, feel free to disregard them in your analysis."
    )
    
    completion = (
        f"Based on the analysis, the provided entry is likely associated with the '{data}' column."
        f"Consider the identified patterns and characteristics, and also remember the alternative names: {source_header}."
    )
    # Extract the 'Alternative_names' feature for the current row
    # completion = headers['Alternative_names']
    
    # Append a dictionary to 'pairs' containing the prompt and completion for the current row
    pairs.append({"prompt": mpt, "completion": completion})

# %%
# # Print column names to identify the correct ones
# print(mapping_df.columns)

# # Iterate through each row in the DataFrame
# for index, headers in mapping_df.iterrows():
#     # Extract relevant information for the current row
#     # Check if the column names exist in your DataFrame
#     if 'data' in mapping_df.columns and 'source_header' in mapping_df.columns:
#         data = headers['data']
#         source_header = headers['source_header']

#         # Construct the prompt (mpt) and completion messages
#         mpt = (
#             f"Examine the provided dataset with column name {data}."
#             f"Alternative names for this column include: {source_header}."
#             # Additional comments (commented out)
#         )
#         completion = (
#             f"Based on the analysis, the provided entry is likely associated with the '{data}' column."
#             f"Consider the identified patterns and characteristics, and also remember the alternative names: {source_header}."
#         )

#         # Print the index along with the prompt and completion
#         print(f"Index: {index}")
#         print(f"Prompt: {mpt}")
#         print(f"Completion: {completion}")
#         print("\n")  # Add a newline for better readability
#     else:
#         print("Column names 'data' and 'source_header' not found in the DataFrame.")

# %%
# pairs = []
# for i in range(len(list_alt)):
#     data_data = ''
#     for j in range(len(datas)):
#         data_data = data_data+ ','+datas[j][i]
#     prompt = (
#         "Enter the value of {} for this altitude:".format(data_labels[i])
#         )
#     completion = ()
    
#     pairs.append({"prompt": prompt, "completion":completion})

# %%
type(pairs)
# Out:
# list

# %%
# Create a file named "prompt_pairs.json" and open it for writing
with open("prompt_updated_terms.json", 'w') as f:
    # Dump the 'pairs' list into the JSON file
    json.dump(pairs, f)

# %%
# Specify the path to the input JSON file
input_json_file = "prompt_updated_terms.json"

# Specify the path to the output JSON Lines file
output_jsonl_file = "prompt_updated_terms_1.jsonl"

# Read the JSON file
with open(input_json_file, 'r') as f:
    data = json.load(f)

# Write JSON Lines to the output file
with open(output_jsonl_file, 'w') as f:
    for item in data:
        json_line = json.dumps(item)
        f.write(json_line + '\n')

# %%
# import json

# # Specify the path to the input JSON file
# input_json_file = "prompt_updated_terms.json"

# # Specify the path to the output JSON Lines file
# output_jsonl_file = "prompt_updated_terms_1.jsonl"

# # Read the JSON file
# with open(input_json_file, 'r') as f:
#     data = json.load(f)

# # Write chat-based format to the output file
# with open(output_jsonl_file, 'w') as f:
#     for item in data:
#         # Write system message
#         system_message = {"role": "system", "content": "You are a helpful assistant."}
#         f.write(json.dumps(system_message) + '\n')

#         # Write user message (prompt)
#         user_message = {"role": "user", "content": item["prompt"]}
#         f.write(json.dumps(user_message) + '\n')

#         # Write assistant message (completion)
#         assistant_message = {"role": "assistant", "content": item["completion"]}
#         f.write(json.dumps(assistant_message) + '\n')

# %%
# Run the OpenAI fine-tuning preparation command
# !openai tools fine_tunes.prepare_data -f "prompt_updated_terms.json"
# Out:
# Analyzing...
#
# - Your file contains 9 prompt-completion pairs. In general, we recommend having at least a few hundred examples. We've found that performance tends to linearly increase for every doubling of the number of examples
# - Based on your data it seems like you're trying to fine-tune a model for classification
# - For classification, we recommend you try one of the faster and cheaper models, such as `ada`
# - For classification, you can estimate the expected model performance by keeping a held out dataset, which is not used for training
# - There are 8 duplicated prompt-completion sets. These are rows: [1, 2, 3, 4, 5, 6, 7, 8]
# - There are 9 examples that are very long. These are rows: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# For conditional generation, and for classification the examples shouldn't be longer than 2048 tokens.
# ...

# %%
from openai import OpenAI

# Set your OpenAI API key
api_key = OPENAI_API_KEY

# Initialize the OpenAI client
client = OpenAI(api_key=api_key)

# Now you can use the client for further operations
try:
    response = client.files.create(
        file=open(r"C:\Workspaces\CodeSpaces\Python_Work\ChatGpt_AzureAI\prompt_updated_terms_1.jsonl", "rb"),
        purpose="fine-tune"  # Use 'fine-tune' instead of 'fine-tuning'
    )
# Extract the file ID from the response
    file_id = response.id  # Use the id attribute
    print("File ID:", file_id)
    print(response)
except Exception as e:
    print(f"Error during file upload: {e}")
# Out:
# File ID: file-nkd9W5cpB1p3i0cFoTzKSWW8
# FileObject(id='file-nkd9W5cpB1p3i0cFoTzKSWW8', bytes=167823, created_at=1702988229, filename='prompt_updated_terms_1.jsonl', object='file', purpose='fine-tune', status='uploaded', status_details=None)

# %%
# !openai migrate
# Out:
# Error: Windows is not supported yet in the migration CLI

# %%
import requests

api_key = OPENAI_API_KEY
training_file_id = "file-jHw2Bnd45P5yjmNwxRo7W0Ey"
url = "https://api.openai.com/v1/fine_tuning/jobs"
headers = {"Content-Type": "application/json", "Authorization": f"Bearer {api_key}"}
payload = {"training_file": training_file_id, "model": "gpt-3.5-turbo"}

response = requests.post(url, headers=headers, json=payload)
print(response.json())
# Out:
# {'error': {'message': 'Fine-tuning jobs cannot be created on an Explore plan. You can upgrade to a paid plan on your billing page: https://platform.openai.com/account/billing/overview', 'type': 'invalid_request_error', 'param': None, 'code': 'exceeded_quota'}}

# %%
final_out_df = pd.read_csv('final_out.csv', encoding_errors= 'ignore')
final_out_df
# Out:
#                                          MGA  \
# 0     Arrowhead General Insurance Agency Inc
# 1     Arrowhead General Insurance Agency Inc
# 2     Arrowhead General Insurance Agency Inc
# 3     Arrowhead General Insurance Agency Inc
# 4     Arrowhead General Insurance Agency Inc
# ...                                      ...
# 5331                       Daniel Abrahamsen
# 5332                       Daniel Abrahamsen
# 5333                       Daniel Abrahamsen
# 5334                       Daniel Abrahamsen
# 5335                       Daniel Abrahamsen
#
#                                 Program Name Issuing Company  \
# 0     Arrowhead ES Primary General Liability            TSIC
# 1     Arrowhead ES Primary General Liability            TSIC
# 2     Arrowhead ES Primary General Liability            TSIC
# 3     Arrowhead ES Primary General Liability            TSIC
# 4     Arrowhead ES Primary General Liability            TSIC
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
array = imputer.fit_transform(final_out_df)

df = pd.DataFrame(array,columns=final_out_df.columns)

# %%
array.shape
# Out:
# (5336, 65)

# %%
df.to_csv("Final_updated.csv")

# %%
file = "C:\Workspaces\CodeSpaces\Python_Work\ChatGpt_AzureAI\Prompt_Completion.csv"
