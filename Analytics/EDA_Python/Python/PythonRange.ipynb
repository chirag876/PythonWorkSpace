# %% [markdown]
# **Range function:** Generates the immutable sequence of numbers starting from the given start integer to the stop integer. The range() is a built-in function that returns a range object that consists series of integer numbers, which we can iterate using a for loop.
#
# `syntax: range(start, stop, step)`
#
# **start (optional):** The starting value of the sequence. If omitted, the sequence starts at 0.
#
# **stop:** The end value of the sequence. The sequence ends before this value. Not included in the result.
#
# **step (optional):** The step or increment between each number in the sequence. If omitted, the default step is 1.
#
# ```
# # Generate numbers between 0 to 6
# for i in range(6):
#     print(i)
# ```
#
# `Note`
#
# - If start is omitted, the default value is 0.
#
# - The sequence stops before reaching the stop value.
#
# - If step is omitted, the default value is 1.
#
# - range() doesn't actually generate all the numbers in memory at once; it generates them as needed. This makes it memory efficient, especially when dealing with large ranges.

# %% [markdown]
# **Points to remember about range function:**
# 1. Works with integer only so all the argument must be integer no other data type.
# 2. All three arguments can be -ve or +ve
# 3. the step value can be zero else it will give value error
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Iterating a list using range() and for loop:** when you iterate the list using only loop you can access only its item but when you use range() with loop you can access the index number of each item.
#
# The advantage of using range() to iterate a list is that it allows us to access each item’s index number. Using index numbers, we can access as well as modify list items if required.
#
# Example:
#
# ```
# list1 = ['Jessa', 'Emma', 20, 30, 75.5]
# # iterate a list using range()
# for i in range(len(list1)):
#     print(list1[i])
# ```

# %% [markdown]
# **Reverse Range:** we can display the sequence of numbers produced by a range() function by descending order or reverse order using following two ways:
#
# 1. using negative step value
# 2. use a reversed() function
